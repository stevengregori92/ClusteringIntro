# %% [markdown]
# <a href="https://colab.research.google.com/github/stevengregori92/ClusteringIntro/blob/main/Clustering_with_Sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install luwiji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 MB 34.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.2 MB/s eta 0:00:00
# ...
#   Created wheel for luwiji: filename=luwiji-1.2.1-py2.py3-none-any.whl size=40366830 sha256=c7b80be0a53877e07352b766569d628631881cd3fd7d14b5d69ea5e5cf96f154
#   Stored in directory: /root/.cache/pip/wheels/ba/90/9e/943ac5067e9cdc185d8f029a1d13278acd52839118acc06c9a
# ...
#   Created wheel for jcopml: filename=jcopml-1.2.2-py2.py3-none-any.whl size=32178 sha256=3df91604f0fdf80a40991da4fb1fc71e5102d21d36fa5421db53a136924d608a
#   Stored in directory: /root/.cache/pip/wheels/5e/06/58/749e5f1baf2932285758798a92793d4347888826160b025808
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering, SpectralClustering

from luwiji.cluster import demo

# %%
X1, y1 = demo.blob_data()
X2, y2 = demo.moon_data()
X3, y3 = demo.circle_data()

# %% [markdown]
# #Visualize

# %%
X=X1
plt.scatter(X[:, 0], X[:, 1], s=10)
plt.axis('equal');

# %% [markdown]
# #K-Means Clustering

# %%
X = X1
kmeans = KMeans(n_clusters=4)
member = kmeans.fit_predict(X)
centre= kmeans.cluster_centers_

plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:, 1], c = member,s=10)
plt.scatter(centre[:, 0], centre[:, 1], c='w', edgecolor='k', s=50, linewidths=2)
plt.axis('equal');
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #Cluster Bulan Sabit

# %% [markdown]
# Cluster Gone Wrong

# %%
X = X2
kmeans = KMeans(n_clusters=2)
member = kmeans.fit_predict(X)
centre= kmeans.cluster_centers_

plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:, 1], c = member,s=10)
plt.scatter(centre[:, 0], centre[:, 1], c='w', edgecolor='k', s=50, linewidths=2)
plt.axis('equal');
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #Cluster Donut

# %% [markdown]
# Cluster Gone Wrong

# %%
X = X3
kmeans = KMeans(n_clusters=2)
member = kmeans.fit_predict(X)
centre= kmeans.cluster_centers_

plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:, 1], c = member,s=10)
plt.scatter(centre[:, 0], centre[:, 1], c='w', edgecolor='k', s=50, linewidths=2)
plt.axis('equal');
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #Menentukan K (n_cluster) tanpa label -> Inertia/ Elbow Analysis

# %%
X = X1
score=[]
for k in range(2, 25):
  kmeans = KMeans(n_clusters=k)
  member = kmeans.fit_predict(X)
  score.append(kmeans.inertia_)

plt.figure(figsize=(10,5))
plt.plot(range(2, 25), score, 'r-')
plt.ylabel('inertia')
plt.xlabel('n_clusters');
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# #Menentukan K (n_cluster) tanpa label -> Silhouette Score

# %%
from sklearn.metrics import silhouette_score

# %%
X = X1
score=[]
for k in range(2, 25):
  kmeans = KMeans(n_clusters=k)
  member = kmeans.fit_predict(X)

  siluete = silhouette_score(X, member, metric = 'euclidean')
  score.append(siluete)

plt.figure(figsize=(10,5))
plt.plot(range(2, 25), score, 'r-')
plt.ylabel('inertia')
plt.xlabel('n_clusters');
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# #Spectral Clustering

# %%
X = X2
sc = SpectralClustering(n_clusters = 2, gamma=100)
labels = sc.fit_predict(X)

plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:, 1], c=labels, s=10)
plt.axis('equal');

# %%
X = X3
sc = SpectralClustering(n_clusters = 2, gamma=100)
labels = sc.fit_predict(X)

plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:, 1], c=labels, s=10)
plt.axis('equal');

# %% [markdown]
# #DBSCAN

# %%
X = X3
dbscan = DBSCAN(eps=0.2)
labels = dbscan.fit_predict(X)

plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:, 1], c=labels, s=10)
plt.axis('equal');

# %%
X = X2
dbscan = DBSCAN(eps=0.2)
labels = dbscan.fit_predict(X)

plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:, 1], c=labels, s=10)
plt.axis('equal');

# %% [markdown]
# #AHC

# %%
X = X2
ahc = AgglomerativeClustering(n_clusters=3, linkage='single')
labels = ahc.fit_predict(X)

plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:, 1], c=labels, s=10)
plt.axis('equal');

# %%
X = X3
ahc = AgglomerativeClustering(n_clusters=3, linkage='single')
labels = ahc.fit_predict(X)

plt.figure(figsize=(6,6))
plt.scatter(X[:,0], X[:, 1], c=labels, s=10)
plt.axis('equal');

# %% [markdown]
# #SciPy

# %%
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram

# %%
X, y = demo.blob_data(30)

# %%
Z = linkage(X)

# %% [markdown]
# #get membership

# %%
labels = fcluster(Z, 4, criterion='maxclust')
labels
# Out:
# array([4, 1, 2, 2, 4, 4, 1, 1, 4, 1, 1, 1, 2, 2, 2, 1, 3, 2, 4, 3, 3, 3,
#        3, 2, 2, 4, 3, 4, 4, 3], dtype=int32)

# %%
labels = fcluster(Z, 5, criterion='maxclust')
labels
# Out:
# array([5, 1, 2, 2, 4, 5, 1, 1, 5, 1, 1, 1, 2, 2, 2, 1, 3, 2, 5, 3, 3, 3,
#        3, 2, 2, 5, 3, 4, 5, 3], dtype=int32)

# %% [markdown]
# #Visualize Dendrogram

# %%
plt.figure(figsize=(15,5))
dendrogram(Z);
